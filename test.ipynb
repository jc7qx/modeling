# %%
import pandas as pd
def f():
    for i in range(3):
        globals() [f'a{i}']
a0 = 1
a1="hello"
a2=pd.DataFrame({'a':['x','y','z'],
                'b':[1,2,32]})
a2
# Out:
#    a   b
# 0  x   1
# 1  y   2
# 2  z  32

# %%
def fun():
    globals() ["m"]

# %%
m = 1
print(m)
# Out:
# 1

# %%
list = [a2, pd.DataFrame({"a": ['w','t','c'], "b":[2, 5, 9]})]

# %%
list[0]
# Out:
#    a   b
# 0  x   1
# 1  y   2
# 2  z  32

# %%
list[1]
# Out:
#    a  b
# 0  w  2
# 1  t  5
# 2  c  9

# %%
df = list[0].append(list[1])

# %%
type(list[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#    a   b
# 0  x   1
# 1  y   2
# 2  z  32
# 0  w   2
# 1  t   5
# 2  c   9

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    index  a   b
# 0      0  x   1
# 1      1  y   2
# 2      2  z  32
# 3      0  w   2
# 4      1  t   5
# 5      2  c   9

# %%
df.sample(1)
# Out:
#    index  a  b
# 5      2  c  9

# %%
df
# Out:
#    index  a   b
# 0      0  x   1
# 1      1  y   2
# 2      2  z  32
# 3      0  w   2
# 4      1  t   5
# 5      2  c   9

# %%
df.sample(3, replace=False)
# Out:
#    index  a  b
# 1      1  y  2
# 4      1  t  5
# 3      0  w  2

# %%
df
# Out:
#    index  a   b
# 0      0  x   1
# 1      1  y   2
# 2      2  z  32
# 3      0  w   2
# 4      1  t   5
# 5      2  c   9

# %%
df1 = df.sample(1)

# %%
df1
# Out:
#    index  a  b
# 3      0  w  2

# %%
df1 = df.sample(frac=1)

# %%
df1
# Out:
#    index  a   b
# 4      1  t   5
# 5      2  c   9
# 2      2  z  32
# 0      0  x   1
# 3      0  w   2
# 1      1  y   2

# %%
df2 = df.sample(frac=0.5)

# %%
df2
# Out:
#    index  a  b
# 5      2  c  9
# 3      0  w  2
# 4      1  t  5

# %%
df.head()
# Out:
#    index  a   b
# 0      0  x   1
# 1      1  y   2
# 2      2  z  32
# 3      0  w   2
# 4      1  t   5

# %%
print(df)
# Out:
#    index  a   b
# 0      0  x   1
# 1      1  y   2
# 2      2  z  32
# 3      0  w   2
# 4      1  t   5
# 5      2  c   9

# %%
df.iloc[1:4]
# Out:
#    index  a   b
# 1      1  y   2
# 2      2  z  32
# 3      0  w   2

# %%
import pandas as pd

# %%
testDF = pd.read_csv("../data/train/drug.csv", encoding="utf8")

# %%
testDF.head()
# Out:
#    性別  教育  神智  年齡  每月採尿平均  實際保管長度  違規次數  獎勵次數  犯次  一年內次數  二年內次數  三年內次數  四年內次數  \
# 0   1   4   3   3   2.333       1     0     0   5      0      0      0      3
# 1   1   3   2   3   0.000       1     0     0   2      0      0      0      1
# 2   1   3   2   3   1.000       3     0     2   4      0      0      0      0
# 3   1   3   0   4   1.714       1     0     0   5      0      0      0      0
# 4   1   3   0   3   0.871       4     0     1   2      0      0      0      0
#
#    五年內次數  首犯年齡  再犯註記
# 0      4     0     0
# 1      0     0     0
# 2      0     1     0
# 3      0     1     1
# 4      0     0     0

# %%
testdf1 = testDF[testDF.再犯註記==1]
testdf0 = testDF[testDF.再犯註記==0]

# %%
nclass = testDF.groupby("再犯註記")
nclass.size()
# Out:
# 再犯註記
# 0    53906
# 1    11496
# dtype: int64

# %%
import matplotlib.pyplot as plt
nclass.size().plot.bar()
# Out:
# <AxesSubplot:xlabel='再犯註記'>

# %%
dd=testdf0.sample(frac=1).iloc[0:10000]
ddd=dd.append(testdf1.sample(10000))

# %%
ddd.sample(frac=1)
# Out:
#        性別  教育  神智  年齡  每月採尿平均  實際保管長度  違規次數  獎勵次數  犯次  一年內次數  二年內次數  三年內次數  \
# 12125   0   3   0   2   1.000       3     0     2   0      0      0      0
# 15577   1   3   0   2   1.556       2     0     1   4      0      0      0
# 22718   1   3   0   4   0.000       1     0     0   4      0      5      3
# 26608   1   2   2   2   1.667       2     1     1   2      0      0      0
# 40032   1   4   3   1   0.778       2     0     0   5      0      0      0
# ...    ..  ..  ..  ..     ...     ...   ...   ...  ..    ...    ...    ...
# 38090   1   3   0   2   2.000       1     0     1   4      0      0      0
# 17875   1   3   0   2   1.367       6     0     0   5      0      0      0
# 5411    0   2   2   2   1.093       6     0     1   4      0      0      0
# 54001   1   2   0   2   1.000       6     0     1   0      0      0      0
# 49422   1   3   0   2   1.400       2     0     0   5      0      0      0
#
#        四年內次數  五年內次數  首犯年齡  再犯註記
# 12125      0      0     0     0
# ...
